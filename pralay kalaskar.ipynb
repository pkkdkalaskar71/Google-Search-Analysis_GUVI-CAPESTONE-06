# %% [markdown]
# # Name :- Pralay K Kalaskar
# # Contact :- +91-7066216365
# # Mail :- pkkdkalaskar71@gmail.com
# # Linkedin :- www.linkedin.com/in/pralay-kalaskar-1010

# %%
# "Tab" = shows all the executable operation with the variable object
# "Lfet shift + Tab" = shows parameters inside that particular function
# "Right Ctrl + Enter" = keyboard shortcut for run In[] in python

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# download pytrends

#try:
#    import pyserial
#except:
#    import pip
#    pip.main(['install','pyserial'])
#    import pyserial

# %%
pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\pralay kalaskar\anaconda3\lib\site-packages (4.9.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from pytrends) (1.4.2)
# Requirement already satisfied: lxml in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from pytrends) (4.8.0)
# Requirement already satisfied: requests>=2.0 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from pytrends) (2.27.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pralay kalaskar\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pip
pip.main(['install','pyserial'])
# Out:
# C:\Users\pralay kalaskar\anaconda3\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: pyserial in c:\users\pralay kalaskar\anaconda3\lib\site-packages (3.5)
# 0

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region() #sorting by region
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10) #Top 10
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   55
# Singapore                  53
# India                      37
# Hong Kong                  29
# Tunisia                    28
# Pakistan                   27
# Sri Lanka                  26
# South Korea                25
# Nepal                      24

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(30, 20))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')

plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# # **Conlusion**
# #### 1) Searches fro Machine Learning started increasing from 2018 & it is rising till date.
#
# #### 2) If we observe top 10 countries, then China has searched most for Machine Learning whereas Nepal is on the 10th position.
#
# #### 3) We can use these kind of analysis for SEO keywords generation that will lead more audience to your site.
